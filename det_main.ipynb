# %%
from detection_utilities import det_utilities

det = det_utilities()

# %%
# -- Inferencing on setA (nano, small, medium, large, v9c)

# -- nano

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setB/nano.pt', # -- only weights are from setB, all others are from setA
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid1.AVI', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA/nano_vid1', 'nano.txt')

# -- small

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setB/small.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid1.AVI', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA/small_vid1', 'small.txt')

# -- medium

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setB/medium.pt',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid1.AVI', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA/medium_vid1', 'medium.txt')

# -- large

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setB/large.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid1.AVI', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA/large_vid1', 'large.txt')

# -- v9c

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setB/v9c.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid1.AVI', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setA/v9c_vid1', 'v9c.txt')

# %%
# -- Inferencing on setB (nano, small, medium, large, v9c)

# -- nano

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setA/nano.pt', # -- only weights are from setA, all others are from setB
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid2.mp4', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB/nano_vid2', 'nano.txt')

# -- small

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setA/small.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid2.mp4', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB/small_vid2', 'small.txt')

# -- medium

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setA/medium.pt',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid2.mp4', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB/medium_vid2', 'medium.txt')

# -- large

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setA/large.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid2.mp4', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB/large_vid2', 'large.txt')

# -- v9c

det.detect_and_process('C:/Users/ashis/Desktop/THESIS/DT_flow/resources/weights/setA/v9c.pt', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/resources/data/wc_vid2.mp4', 
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB',
                       'C:/Users/ashis/Desktop/THESIS/DT_flow/det_models/files/setB/v9c_vid2', 'v9c.txt')
